# %%
import pandas as pd
import numpy as np
import os

# %%
folder = r'C:\Users\panas\OneDrive\Desktop\DataScience\PersonalProjects\PersonalNLP'
mainDf = pd.read_excel(f'{folder}\VideosToAssess.xlsx') #excel file with all videos to be assessed
mainDf = mainDf.rename(columns={'Phone':'Make'})
mainDf['Phone'] = mainDf['Brand'].astype(str) + " " + mainDf['Make'].astype(str)
mainDf
# Out:
#                                                  Link      VideoID    Brand  \
# 0   https://www.youtube.com/watch?v=4JEZ2rrf2N4&ab...  4JEZ2rrf2N4  Samsung
# 1   https://www.youtube.com/watch?v=wXmzpFoHkfA&ab...  wXmzpFoHkfA  Samsung
# 2   https://www.youtube.com/watch?v=z8gOX35dAfc&ab...  z8gOX35dAfc  Samsung
# 3   https://www.youtube.com/watch?v=Mhvv2-iCKao&ab...  Mhvv2-iCKao  Samsung
# 4   https://www.youtube.com/watch?v=1sgeM6DsV40&ab...  1sgeM6DsV40  Samsung
# 5   https://www.youtube.com/watch?v=nNlTNE1y9DM&ab...  nNlTNE1y9DM  Samsung
# 6   https://www.youtube.com/watch?v=Gzy_nCkn88U&ab...  Gzy_nCkn88U  Samsung
# 7   https://www.youtube.com/watch?v=Lg8B4aTZf7o&ab...  Lg8B4aTZf7o  Samsung
# 8   https://www.youtube.com/watch?v=-wOdL7HFNOs&ab...   wOdL7HFNOs  Samsung
# 9   https://www.youtube.com/watch?v=tn2AgrwXpNQ&t=...  tn2AgrwXpNQ  Samsung
# 10  https://www.youtube.com/watch?v=vXIAB_1FEC0&t=...  vXIAB_1FEC0  Samsung
# ...

# %%
import requests
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api.formatters import JSONFormatter

formatter = JSONFormatter()

def get_youtube_details(video_id, api_key):
    """
    Fetches video metadata, statistics, and transcript from the YouTube Data API v3.
    
    Parameters:
    - video_id (str): The YouTube video ID.
    - api_key (str): The API key to authenticate with the YouTube API.
    
    Returns:
    - dict: A dictionary containing video details like title, publish date, statistics, 
            max resolution thumbnail, and the video transcript.
    """
    base_url = "https://www.googleapis.com/youtube/v3/videos"
    params = {
        "part": "snippet,statistics", # Fetches statistics
        "id": video_id, 
        "key": api_key
    }

    response = requests.get(base_url, params=params)
    data = response.json()
    
    # Check if the 'items' key exists in the API response
    if not data.get("items"):
        print("Error:", data)
        return None
    
    title = data["items"][0]["snippet"]["title"]
    published_at = data["items"][0]["snippet"]["publishedAt"]
    statistics = data["items"][0]["statistics"]
    
    # Get the max resolution thumbnail
    thumbnails = data["items"][0]["snippet"]["thumbnails"]
    maxres_thumbnail = thumbnails.get("maxres", {}).get("url")
    if not maxres_thumbnail:
        # Fallback to other resolutions if maxres is not available
        maxres_thumbnail = thumbnails.get("high", {}).get("url") or thumbnails.get("medium", {}).get("url")

    # Get the transcript
    try:
        transcript = YouTubeTranscriptApi.get_transcript(video_id)
        formatted_transcript = formatter.format_transcript(transcript)
    except:
        formatted_transcript = None

    return {
        "videoId": video_id,
        "title": title,
        "publishedAt": published_at,
        "statistics": statistics,
        "maxresThumbnail": maxres_thumbnail,
        "transcript": formatted_transcript
    }

# %%
import time

def get_details_for_multiple_videos(video_ids, api_key): #add your api key
    all_video_details = []
    failed_video_ids = []

    for video_id in video_ids:
        print(f"Processing video ID: {video_id}")
        try:
            details = get_youtube_details(video_id, api_key)
            if details:  # Check if details is not None
                all_video_details.append(details)
        except Exception as e:
            print(f"Failed to retrieve details for video ID: {video_id}. Reason: {e}")
            failed_video_ids.append(video_id)
        time.sleep(2)

    # Convert the list of video details to a DataFrame
    df = pd.DataFrame(all_video_details)

    # Return the DataFrame and the list of failed video IDs
    return df, failed_video_ids

# %%
api_key = 'AIzaSyCJvI_udalHYzy-qr7CcFYYOA6Rcqh_P2o'

# %%
allVideoIDs = mainDf['VideoID'].tolist()

# %%
video_details_df, failed_ids = get_details_for_multiple_videos(allVideoIDs, api_key)
video_details_df
# Out:
# Processing video ID: 4JEZ2rrf2N4
# Processing video ID: wXmzpFoHkfA
# Processing video ID: z8gOX35dAfc
# Processing video ID: Mhvv2-iCKao
# Processing video ID: 1sgeM6DsV40
# Processing video ID: nNlTNE1y9DM
# Processing video ID: Gzy_nCkn88U
# Processing video ID: Lg8B4aTZf7o
# Processing video ID: wOdL7HFNOs
# Error: {'kind': 'youtube#videoListResponse', 'etag': 'YIUPVpqNjppyCWOZfL-19bLb7uk', 'items': [], 'pageInfo': {'totalResults': 0, 'resultsPerPage': 0}}
# Processing video ID: tn2AgrwXpNQ
# Processing video ID: vXIAB_1FEC0
# Processing video ID: zhoTX0RRXPQ
# Processing video ID: uBEaG6n0XDs
# Processing video ID: 61TAqY03xwk
# Processing video ID: 0Ae0YwmgYTY
# Processing video ID: ld5H2L4j6LE
# Processing video ID: 9Ca8zWJOlFQ
# Processing video ID: DyX-QZZBgpw
# Processing video ID: eWI_BtcDJu0
# Processing video ID: TnkdoEZhTbc
# Processing video ID: SdLShOCvVeM
# Processing video ID: 0X0Jm8QValY
# Processing video ID: LR708uA4zQ8
# Processing video ID: KvNis_A6UaI
# ...

# %%
failed_ids #these videos did not return a video ID
# Out:
# []

# %%
mainDf = mainDf[~mainDf['VideoID'].isin(failed_ids)] #remove links without transcripts
mainDf
# Out:
#                                                  Link      VideoID    Brand  \
# 0   https://www.youtube.com/watch?v=4JEZ2rrf2N4&ab...  4JEZ2rrf2N4  Samsung
# 1   https://www.youtube.com/watch?v=wXmzpFoHkfA&ab...  wXmzpFoHkfA  Samsung
# 2   https://www.youtube.com/watch?v=z8gOX35dAfc&ab...  z8gOX35dAfc  Samsung
# 3   https://www.youtube.com/watch?v=Mhvv2-iCKao&ab...  Mhvv2-iCKao  Samsung
# 4   https://www.youtube.com/watch?v=1sgeM6DsV40&ab...  1sgeM6DsV40  Samsung
# 5   https://www.youtube.com/watch?v=nNlTNE1y9DM&ab...  nNlTNE1y9DM  Samsung
# 6   https://www.youtube.com/watch?v=Gzy_nCkn88U&ab...  Gzy_nCkn88U  Samsung
# 7   https://www.youtube.com/watch?v=Lg8B4aTZf7o&ab...  Lg8B4aTZf7o  Samsung
# 8   https://www.youtube.com/watch?v=-wOdL7HFNOs&ab...   wOdL7HFNOs  Samsung
# 9   https://www.youtube.com/watch?v=tn2AgrwXpNQ&t=...  tn2AgrwXpNQ  Samsung
# 10  https://www.youtube.com/watch?v=vXIAB_1FEC0&t=...  vXIAB_1FEC0  Samsung
# ...

# %%
#join videodetails and maindf
allWorkingTrans = pd.merge(video_details_df, mainDf, left_on='videoId', right_on='VideoID', how='inner').drop(columns=['VideoID'])
allWorkingTrans.head() #perform a join between stats and transcripts
# Out:
#        videoId                        title           publishedAt  \
# 0  4JEZ2rrf2N4  Samsung Galaxy SIII Review!  2012-06-26T01:23:05Z
# 1  wXmzpFoHkfA    Samsung Galaxy S4 Review!  2013-05-01T00:50:25Z
# 2  z8gOX35dAfc    Samsung Galaxy S5 Review!  2014-04-16T23:52:30Z
# 3  Mhvv2-iCKao    Samsung Galaxy S6 Review!  2015-04-22T05:31:26Z
# 4  1sgeM6DsV40    Samsung Galaxy S7 Review!  2016-03-17T22:31:12Z
#
#                                           statistics  \
# 0  {'viewCount': '577203', 'likeCount': '10138', ...
# 1  {'viewCount': '1846289', 'likeCount': '20489',...
# 2  {'viewCount': '2066473', 'likeCount': '32166',...
# 3  {'viewCount': '5745164', 'likeCount': '101281'...
# 4  {'viewCount': '5546706', 'likeCount': '99938',...
#
#                                      maxresThumbnail  \
# 0  https://i.ytimg.com/vi/4JEZ2rrf2N4/maxresdefau...
# 1  https://i.ytimg.com/vi/wXmzpFoHkfA/maxresdefau...
# 2  https://i.ytimg.com/vi/z8gOX35dAfc/maxresdefau...
# ...

# %%
# Metadata DataFrame
metadata_df = allWorkingTrans.drop(columns=['transcript'])
# Transcript DataFrame
transcript_df = allWorkingTrans[['videoId', 'transcript']]

# %%
# !pip install transformers
# !pip install tensorflow
# !pip install DeepSegment
# !pip install sentencepiece
from tensorflow import keras
# Out:
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\panas\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\panas\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\panas\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\panas\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\panas\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# ...

# %%
# !pip install tensorflow
import tensorflow as tf
import sentencepiece
from transformers import T5Tokenizer, TFT5ForConditionalGeneration
# Out:
# ...
#   Obtaining dependency information for keras<2.14,>=2.13.1 from https://files.pythonhosted.org/packages/2e/f3/19da7511b45e80216cbbd9467137b2d28919c58ba1ccb971435cb631e470/keras-2.13.1-py3-none-any.whl.metadata
#   Using cached keras-2.13.1-py3-none-any.whl.metadata (2.4 kB)
# ...
# Using cached keras-2.13.1-py3-none-any.whl (1.7 MB)
# ...
#   Attempting uninstall: keras
#     Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\panas\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\panas\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages)
# ...

# %%
def extract_plain_text_from_transcript(transcript_list):
    """
    Extract plain text from a list of transcript dictionaries.
    
    Parameters:
    - transcript_list (list): List of transcript dictionaries.
    
    Returns:
    - str: Concatenated plain text.
    """
    plainText = []
    for dictionary in transcript_list:
        for key, value in dictionary.items():
            if key == 'text':
                plainText.append(value)
                plainText.append(' ')
    return ''.join(plainText)

# %%
import numpy as np
import torch
import pandas as pd
import ast
from transformers import DistilBertTokenizerFast, DistilBertForTokenClassification

# Initialize the DistilBert model and tokenizer for punctuation
checkpoint = "unikei/distilbert-base-re-punctuate"
tokenizer = DistilBertTokenizerFast.from_pretrained(checkpoint)
model = DistilBertForTokenClassification.from_pretrained(checkpoint)
encoder_max_length = 256

def extract_plain_text_from_transcript(transcript_list):
    """
    Extract plain text from a list of transcript dictionaries.
    
    - str: Concatenated plain text.
    """
    plainText = []
    for dictionary in transcript_list:
        for key, value in dictionary.items():
            if key == 'text':
                plainText.append(value)
                plainText.append(' ')
    return ''.join(plainText)

def split_to_segments(wrds, length, overlap):
    """
    Split the words into segments of a specified length with a specified overlap.
    Returns:
    - list: List of segments (dictionaries) with text and start/end indices.
    """
    resp = []
    i = 0
    while True:
        wrds_split = wrds[(length * i):((length * (i + 1)) + overlap)]
        if not wrds_split:
            break
        resp_obj = {
            "text": wrds_split,
            "start_idx": length * i,
            "end_idx": (length * (i + 1)) + overlap,
        }
        resp.append(resp_obj)
        i += 1
    return resp

def punctuate_wordpiece(wordpiece, label):
    """
    Punctuate a wordpiece based on its label.
    Returns:
    - str: Punctuated wordpiece.
    """
    if label.startswith('UPPER'):
        wordpiece = wordpiece.upper()
    elif label.startswith('Upper'):
        wordpiece = wordpiece[0].upper() + wordpiece[1:]
    if label[-1] != '_' and label[-1] != wordpiece[-1]:
        wordpiece += label[-1]
    return wordpiece

def punctuate_segment(wordpieces, word_ids, labels, start_word):
    """
    Punctuate a segment of wordpieces based on their labels.
    - start_word (int): Word ID to start from.
    Returns:
    - str: Punctuated text segment.
    """
    result = ''
    for idx in range(0, len(wordpieces)):
        if word_ids[idx] == None:
            continue
        if word_ids[idx] < start_word:
            continue
        wordpiece = punctuate_wordpiece(wordpieces[idx][2:] if wordpieces[idx].startswith('##') else wordpieces[idx],
                                        labels[idx])
        if idx > 0 and len(result) > 0 and word_ids[idx] != word_ids[idx - 1] and result[-1] != '-':
            result += ' '
        result += wordpiece
    return result

def process_segment(words, tokenizer, model, start_word):
    """
    Tokenize, predict punctuation, and punctuate a text segment.
    Parameters:
    - words (dict): Dictionary with the text segment and start/end indices.
    - tokenizer (DistilBertTokenizerFast): Tokenizer for text processing.
    - model (DistilBertForTokenClassification): Model for punctuation prediction.
    - start_word (int): Word ID to start from.
    Returns:
    - str: Punctuated text segment.
    """
    tokens = tokenizer(words['text'],
                       padding="max_length",
                       max_length=encoder_max_length,
                       is_split_into_words=True, return_tensors='pt')
    
    with torch.no_grad():
        logits = model(**tokens).logits
    logits = logits.cpu()
    predictions = np.argmax(logits, axis=-1)
    wordpieces = tokens.tokens()
    word_ids = tokens.word_ids()
    id2label = model.config.id2label
    labels = [[id2label[p.item()] for p in prediction] for prediction in predictions][0]
    return punctuate_segment(wordpieces, word_ids, labels, start_word)

def punctuate(text, tokenizer, model):
    """
    Punctuate text of any length.
    Parameters:
    - text (str): Text to punctuate.
    - tokenizer (DistilBertTokenizerFast): Tokenizer for text processing.
    - model (DistilBertForTokenClassification): Model for punctuation prediction.
    Returns:
    - str: Punctuated text.
    """
    text = text.lower()
    text = text.replace('\n', ' ')
    words = text.split(' ')
    overlap = 50
    slices = split_to_segments(words, 150, 50)
    result = ""
    start_word = 0
    for text in slices:
        corrected = process_segment(text, tokenizer, model, start_word)
        result += corrected + ' '
        start_word = overlap
    return result

def punctuate_transcript(plainTranscript):
    """
    Punctuate a list of transcript dictionaries.
    Parameters:
    - transcript_list (list): List of transcript dictionaries.
    Returns:
    - str: Punctuated transcript.
    """
    punctuated_version = punctuate(plainTranscript, tokenizer, model)
    return punctuated_version

def punctuate_transcripts_in_dataframe(df):
    """
    Punctuates the transcripts in the 'transcript' column of the given dataframe.
    Parameters:
    - df (pd.DataFrame): DataFrame containing a 'transcript' column.
    Returns:
    - pd.DataFrame: DataFrame with punctuated transcripts.
    """
    df['punctuated_transcript'] = df['transcript'].apply(
        lambda x: punctuate_transcript(extract_plain_text_from_transcript(ast.literal_eval(x))) if x and isinstance(x, str) else None
    )
    return df

# %%
df_with_punctuated_transcripts = punctuate_transcripts_in_dataframe(allWorkingTrans)

# %%
df_with_punctuated_transcripts.head()
# Out:
#        videoId                        title           publishedAt  \
# 0  4JEZ2rrf2N4  Samsung Galaxy SIII Review!  2012-06-26T01:23:05Z
# 1  wXmzpFoHkfA    Samsung Galaxy S4 Review!  2013-05-01T00:50:25Z
# 2  z8gOX35dAfc    Samsung Galaxy S5 Review!  2014-04-16T23:52:30Z
# 3  Mhvv2-iCKao    Samsung Galaxy S6 Review!  2015-04-22T05:31:26Z
# 4  1sgeM6DsV40    Samsung Galaxy S7 Review!  2016-03-17T22:31:12Z
#
#                                           statistics  \
# 0  {'viewCount': '577203', 'likeCount': '10138', ...
# 1  {'viewCount': '1846289', 'likeCount': '20489',...
# 2  {'viewCount': '2066473', 'likeCount': '32166',...
# 3  {'viewCount': '5745164', 'likeCount': '101281'...
# 4  {'viewCount': '5546706', 'likeCount': '99938',...
#
#                                      maxresThumbnail  \
# 0  https://i.ytimg.com/vi/4JEZ2rrf2N4/maxresdefau...
# 1  https://i.ytimg.com/vi/wXmzpFoHkfA/maxresdefau...
# 2  https://i.ytimg.com/vi/z8gOX35dAfc/maxresdefau...
# ...

# %%
df_with_punctuated_transcripts['punctuated_transcript'] = df_with_punctuated_transcripts['punctuated_transcript'].str.replace('[Music]', '', regex=False)
df_with_punctuated_transcripts['punctuated_transcript'] = df_with_punctuated_transcripts[('punctuated_transcript')].str.replace('Upbeat music', '', regex=False)

# %%
semantic_dict = {
    'DESIGN': ['flat edges'],
    
    'BUILD_QUALITY': ['speaker', 'glass'],
    
    'BATTERY_OR_CHARGING': ['fast charge', 'wireless charging', 'drain', 'screen on time', 'usage time'],
    
    'CAMERA': ['camera', 'lens', 'megapixel', 'MP', 'portrait', 'photo', 'image', 'picture', 'shutter', 'zoom', 'flash', 'low light', 'sensor', 'resolution', 'video', 'optical'],
    
    'SCREEN_OR_DISPLAY': ['hz', 'OLED', 'LCD', 'herz', 'nits', 'refresh rate','bezel'],
    
    'PHONE_PERFORMANCE': ['processor', 'CPU', 'GPU', 'RAM', 'memory', 'storage', 'multitasking']
}

def semantic_replacement(text, semantic_dict):
    for key, values in semantic_dict.items():
        for value in values:
            text = text.replace(value, key)
    return text #perform semantic replacement of key terms that occur often

# %%
# Applying the function on the 'punctuated_transcript' column
df_with_punctuated_transcripts['semantically_replaced_transcript'] = allWorkingTrans['punctuated_transcript'].apply(lambda x: semantic_replacement(x, semantic_dict) if isinstance(x, str) else x)

# %%
punctuated_df = df_with_punctuated_transcripts

# %%
from nltk.tokenize import sent_tokenize

def process_text_into_batches(r, batch_size=2):
    """Tokenizes text into sentences and then batches sentences.
    
    Args:
    - r (str): The input text to be processed.
    - batch_size (int, optional): Number of sentences per batch. Defaults to 2.
    
    Returns:
    - List[str]: List of text batches.
    """
    
    sentences = sent_tokenize(r)

    def batch_sentences(sentences, batch_size=2):
        batches = []  # Create an empty list to hold batches of sentences
        for i in range(0, len(sentences), batch_size):  # Loop in steps of batch_size
            batch = sentences[i:i+batch_size]  # Extract a slice of sentences to form a batch
            batches.append(batch)  # Add this batch to the list of batches
        return batches

    batched = batch_sentences(sentences, batch_size)
    
    flatBatch = []
    for sublist in batched:
        combined = ' '.join(sublist)
        flatBatch.append(combined)

    return flatBatch

# %%
punctuated_df.head(5)
 #remove music detection
#punctuated_df = punctuated_df.drop('Unnamed: 0', axis = 1)
# Out:
#        videoId                        title           publishedAt  \
# 0  4JEZ2rrf2N4  Samsung Galaxy SIII Review!  2012-06-26T01:23:05Z
# 1  wXmzpFoHkfA    Samsung Galaxy S4 Review!  2013-05-01T00:50:25Z
# 2  z8gOX35dAfc    Samsung Galaxy S5 Review!  2014-04-16T23:52:30Z
# 3  Mhvv2-iCKao    Samsung Galaxy S6 Review!  2015-04-22T05:31:26Z
# 4  1sgeM6DsV40    Samsung Galaxy S7 Review!  2016-03-17T22:31:12Z
#
#                                           statistics  \
# 0  {'viewCount': '577203', 'likeCount': '10138', ...
# 1  {'viewCount': '1846289', 'likeCount': '20489',...
# 2  {'viewCount': '2066473', 'likeCount': '32166',...
# 3  {'viewCount': '5745164', 'likeCount': '101281'...
# 4  {'viewCount': '5546706', 'likeCount': '99938',...
#
#                                      maxresThumbnail  \
# 0  https://i.ytimg.com/vi/4JEZ2rrf2N4/maxresdefau...
# 1  https://i.ytimg.com/vi/wXmzpFoHkfA/maxresdefau...
# 2  https://i.ytimg.com/vi/z8gOX35dAfc/maxresdefau...
# ...

# %%
from setfit import SetFitModel
model = SetFitModel.from_pretrained("datanash/mkbhd5pillars") #load bespoke training model

# %%
preds = model(["the super hdr photos", "fingerprint sensor"])
def map_int_to_label(value): #convert int output to labels
    label_dict = {
        0: 'Battery or Charging',
        1: 'Build quality',
        2: 'Camera',
        3: 'Design',
        4: 'Phone performance',
        5: 'Price',
        6: 'Screen or Display',
        7: 'Unknown'
    }
    return label_dict.get(value, "Unknown")

label_preds = [map_int_to_label(val.item()) for val in preds]

print(label_preds)
# Out:
# ['Camera', 'Phone performance']

# %%
from transformers import pipeline

# %%
classifier = pipeline(task="text-classification", model="SamLowe/roberta-base-go_emotions", top_k=None)

sentences = ["But something definitely worth mentioning the toggles themselves are pretty much all really useful And I'm really glad that they're part of touch was definitely one of my favorite features. Now that three button layout at the bottom some people love it, some people really hate it actually."]

model_outputs = classifier(sentences)
print(model_outputs[0])
# produces a list of dicts for each of the labels
# Out:
# [{'label': 'love', 'score': 0.7346780896186829}, {'label': 'approval', 'score': 0.2705245018005371}, {'label': 'joy', 'score': 0.24171815812587738}, {'label': 'admiration', 'score': 0.1386135220527649}, {'label': 'annoyance', 'score': 0.024480637162923813}, {'label': 'disapproval', 'score': 0.021006539463996887}, {'label': 'neutral', 'score': 0.020244162529706955}, {'label': 'anger', 'score': 0.015985757112503052}, {'label': 'realization', 'score': 0.011286797001957893}, {'label': 'excitement', 'score': 0.007659750059247017}, {'label': 'disappointment', 'score': 0.007537226192653179}, {'label': 'caring', 'score': 0.006665227003395557}, {'label': 'relief', 'score': 0.00627903314307332}, {'label': 'gratitude', 'score': 0.005525464657694101}, {'label': 'amusement', 'score': 0.004929953254759312}, {'label': 'pride', 'score': 0.00464902026578784}, {'label': 'optimism', 'score': 0.003913654014468193}, {'label': 'sadness', 'score': 0.003840730292722583}, {'label': 'disgust', 'score': 0.0038
# ...

# %%
from nltk.tokenize import sent_tokenize
from transformers import pipeline, DistilBertTokenizer
from setfit import SetFitModel

# Initialize the SetFit model for theme prediction
model = SetFitModel.from_pretrained("datanash/mkbhd5pillars")

# Initialize sentiment model
sentiment_model = pipeline("sentiment-analysis", model="nlptown/bert-base-multilingual-uncased-sentiment")

# Initialize emotion classifier
emotion_classifier = pipeline(task="text-classification", model="SamLowe/roberta-base-go_emotions")

def map_int_to_label(value):
    label_dict = {
        0: 'Battery or Charging',
        1: 'Build quality',
        2: 'Camera',
        3: 'Design',
        4: 'Phone performance',
        5: 'Price',
        6: 'Screen or Display',
        7: 'Unknown'
    }
    return label_dict.get(value, "Unknown")

transcript_count = 1  # Global variable to keep track of transcripts

# Initialize tokenizer for checking token length
tokenizer_for_length = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')

def get_theme_and_sentiment(transcript):
    global transcript_count
    sentences = sent_tokenize(transcript)
    batched_sentences = [sentences[i:i+2] for i in range(0, len(sentences), 2)]
    
    results = []
    batch_count = 0.1
    for batch in batched_sentences:
        combined_text = ' '.join(batch)
        
        # Check token length and adjust if necessary
        tokenized_length = len(tokenizer_for_length.tokenize(combined_text))
        if tokenized_length > 512:
            tokens = tokenizer_for_length.tokenize(combined_text)
            chunks = [tokens[i:i+200] for i in range(0, len(tokens), 200)]
            themes = []
            sentiments = []
            emotions = []
            for chunk in chunks:
                chunk_text = tokenizer_for_length.convert_tokens_to_string(chunk)
                
                # Print the chunk text being processed
                print(f"Processing chunk: {chunk_text}")
                
                # Predict theme
                theme_pred = model([chunk_text])  
                themes.append(map_int_to_label(theme_pred[0].item()))

                # Predict sentiment
                sentiments.append(sentiment_model(chunk_text)[0]['label'])

                # Predict emotion
                emotions.append(emotion_classifier(chunk_text)[0]['label'])
            
            # Using mode (most frequent) theme, sentiment, and emotion for the entire batch
            theme = max(set(themes), key=themes.count)
            sentiment = max(set(sentiments), key=sentiments.count)
            emotion = max(set(emotions), key=emotions.count)
        else:
            # Print the batch text being processed
            print(f"Processing: {combined_text}")
            
            # Predict theme
            theme_pred = model([combined_text])
            theme = map_int_to_label(theme_pred[0].item())
            
            # Predict sentiment
            sentiment = sentiment_model(combined_text)[0]['label']

            # Predict emotion
            emotion = emotion_classifier(combined_text)[0]['label']
        
        results.append({
            'batch_text': combined_text,
            'theme': theme,
            'sentiment': sentiment,
            'emotion': emotion
        })
        
        # Print counts for tracking
        print(f"Finished processing transcript {transcript_count} - batch {round(transcript_count + batch_count, 1)}")
        
        batch_count += 0.1
    
    transcript_count += 1
    return results

punctuated_df['punctuated_transcript'] = punctuated_df['punctuated_transcript'].astype(str)
punctuated_df['predictions'] = punctuated_df['semantically_replaced_transcript'].apply(get_theme_and_sentiment)
# Out:
# Processing: The Samsung Galaxy S3 is probably the most wanted Android phone of the entire year 2012. Samsung has delivered So without any further ado, let's go ahead and take a look at the full review.
# Finished processing transcript 1 - batch 1.1
# ...

# %%
# First, let's check if the 'statistics' column is of type string
if isinstance(allWorkingTrans['statistics'].iloc[0], str):
    # Convert strings to dictionaries
    allWorkingTrans['statistics'] = allWorkingTrans['statistics'].apply(eval)

# Unpack the statistics dictionary column
statistics_df = allWorkingTrans['statistics'].apply(pd.Series)

# Drop the original 'statistics' column and concatenate with the unpacked columns
allWorkingTrans = pd.concat([allWorkingTrans.drop('statistics', axis=1), statistics_df], axis=1)

# Drop any unnamed columns and the 'transcript' column
allWorkingTrans = allWorkingTrans.loc[:, ~allWorkingTrans.columns.str.contains('^Unnamed')]
allWorkingTrans = allWorkingTrans.drop('transcript', axis=1)

# Convert 'publishedAt' to regular date format
allWorkingTrans['publishedAt'] = pd.to_datetime(allWorkingTrans['publishedAt']).dt.strftime('%d/%m/%Y')

print(allWorkingTrans.head())
# Out:
#        videoId                        title publishedAt  \
# 0  4JEZ2rrf2N4  Samsung Galaxy SIII Review!  26/06/2012
# 1  wXmzpFoHkfA    Samsung Galaxy S4 Review!  01/05/2013
# 2  z8gOX35dAfc    Samsung Galaxy S5 Review!  16/04/2014
# 3  Mhvv2-iCKao    Samsung Galaxy S6 Review!  22/04/2015
# 4  1sgeM6DsV40    Samsung Galaxy S7 Review!  17/03/2016
#
#                                      maxresThumbnail  \
# 0  https://i.ytimg.com/vi/4JEZ2rrf2N4/maxresdefau...
# 1  https://i.ytimg.com/vi/wXmzpFoHkfA/maxresdefau...
# 2  https://i.ytimg.com/vi/z8gOX35dAfc/maxresdefau...
# 3  https://i.ytimg.com/vi/Mhvv2-iCKao/maxresdefau...
# 4  https://i.ytimg.com/vi/1sgeM6DsV40/maxresdefau...
#
#                                                 Link    Brand Make  \
# 0  https://www.youtube.com/watch?v=4JEZ2rrf2N4&ab...  Samsung   s3
# 1  https://www.youtube.com/watch?v=wXmzpFoHkfA&ab...  Samsung   s4
# 2  https://www.youtube.com/watch?v=z8gOX35dAfc&ab...  Samsung   s5
# ...

# %%
# Initialize a list to hold the flattened data
flat_data = []

# Loop through each row of the DataFrame to extract predictions
for idx, row in punctuated_df.iterrows():
    video_id = row['videoId']
    for pred in row['predictions']:
        batch_text = pred['batch_text']
        theme = pred['theme']
        sentiment = pred['sentiment']
        emotion = pred['emotion']
        flat_data.append([video_id, batch_text, theme, sentiment,emotion])

# Convert the flattened list to a DataFrame
final_df = pd.DataFrame(flat_data, columns=['videoId', 'batch_text', 'theme', 'sentiment', 'emotion'])

# Add the batch_counter
final_df['batch_counter'] = final_df.groupby('videoId').cumcount() + 1

final_df
# Out:
#           videoId                                         batch_text  \
# 0     4JEZ2rrf2N4  The Samsung Galaxy S3 is probably the most wan...
# 1     4JEZ2rrf2N4  So this is Samsung's flagship device worldwide...
# 2     4JEZ2rrf2N4  The biggest new feature of them all literally ...
# 3     4JEZ2rrf2N4  I mean it's the fastest it's the lightest of t...
# 4     4JEZ2rrf2N4  There are a few minor changes like the setting...
# ...           ...                                                ...
# 1919  3yEP4ooj1WI  it's the same thing it very well thought out i...
# 1920  3yEP4ooj1WI  So, yeah, that's, that's what feels like sort ...
# 1921  3yEP4ooj1WI  No, I'm not going to give them full redemption...
# 1922  3yEP4ooj1WI  So now, I just hope they keep it going. you kn...
# 1923  3yEP4ooj1WI     Catch you guys in the next one. Peace [music],
#
#                   theme sentiment      emotion  batch_counter
# 0               Unknown   5 stars      neutral              1
# ...

# %%
final_df.head()
def extract_sentiment(sentiment_str):
    return int(sentiment_str[0])
final_df['Sentiment Number'] = final_df['sentiment'].apply(extract_sentiment)

len(allWorkingTrans)
# Out:
# 45

# %%
final_df.to_excel(r'C:\Users\panas\OneDrive\Desktop\DataScience\PersonalProjects\PersonalNLP\ScriptLevel.xlsx', sheet_name="script")
allWorkingTrans.to_excel(r'C:\Users\panas\OneDrive\Desktop\DataScience\PersonalProjects\PersonalNLP\videoMetaData.xlsx', sheet_name="meta")
